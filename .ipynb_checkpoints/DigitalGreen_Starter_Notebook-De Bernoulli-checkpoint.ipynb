# %%
# Import libraries
import pandas as pd
import numpy as np
import datetime
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import seaborn as sn

# %%
pd.set_option('display.max_columns', None)

# %%
# Load files
data_path = ''
train = pd.read_csv(data_path + 'Train.csv')
test = pd.read_csv(data_path + 'Test.csv')
sample_submission = pd.read_csv(data_path + 'SampleSubmission.csv')
var_desc = pd.read_csv(data_path + 'VariableDescription.csv')

# %%
test
# Out:
#                    ID  District      Block  CultLand  CropCultLand  \
# 0     ID_F9XXEXN2ADR2     Jamui     Khaira        20            13
# 1     ID_SO3VW2X4QO93     Jamui     Khaira        25            25
# 2     ID_UKUQ7JM8E894   Nalanda     Rajgir        30            30
# 3     ID_QUISMWEZR2H4  Vaishali      Mahua        15            10
# 4     ID_25JGI455VKCZ   Nalanda     Rajgir        30            10
# ...               ...       ...        ...       ...           ...
# 1285  ID_6MMECMX3B728     Jamui     Khaira        20            16
# 1286  ID_GZ9YGWCLLMKN  Vaishali      Mahua        25            14
# 1287  ID_01YVA2LJVYBR  Vaishali     Garoul        10             3
# 1288  ID_YQRL2IOUU4SZ     Jamui      Jamui        10            10
# 1289  ID_VAX2N8ELPEZE   Nalanda  Noorsarai        15            15
#
#                                   LandPreparationMethod CropTillageDate  \
# 0                                         TractorPlough      2022-07-24
# 1                                         TractorPlough      2022-07-24
# 2     WetTillagePuddling TractorPlough FourWheelTrac...      2022-07-07
# 3     WetTillagePuddling TractorPlough BullockPlough...      2022-07-04
# 4     WetTillagePuddling TractorPlough FourWheelTrac...      2022-07-21
# ...                                                 ...             ...
# 1285                                      TractorPlough      2022-07-23
# 1286  WetTillagePuddling TractorPlough FourWheelTrac...      2022-07-07
# 1287                                      TractorPlough      2022-07-06
# 1288                        TractorPlough BullockPlough      2022-07-22
# 1289               TractorPlough FourWheelTracRotavator      2022-07-08
#
#       CropTillageDepth         CropEstMethod RcNursEstDate  \
# 0                    4    Manual_PuddledLine    2022-07-03
# 1                    5  Manual_PuddledRandom    2022-07-08
# 2                    5  Manual_PuddledRandom    2022-06-24
# 3                    5  Manual_PuddledRandom    2022-06-20
# 4                    3  Manual_PuddledRandom    2022-06-24
# ...                ...                   ...           ...
# 1285                 4    Manual_PuddledLine    2022-07-05
# 1286                 5  Manual_PuddledRandom    2022-07-09
# 1287                 6    Manual_PuddledLine    2022-06-18
# 1288                 4  Manual_PuddledRandom    2022-06-18
# 1289                 4  Manual_PuddledRandom    2022-06-22
#
#      SeedingSowingTransplanting  SeedlingsPerPit  \
# 0                    2022-07-29              1.0
# 1                    2022-08-02              4.0
# 2                    2022-07-08              2.0
# 3                    2022-07-10              2.0
# 4                    2022-07-22              1.0
# ...                         ...              ...
# 1285                 2022-07-30              1.0
# 1286                 2022-07-25              2.0
# 1287                 2022-07-09              1.0
# 1288                 2022-07-26              4.0
# 1289                 2022-07-13              1.0
#
#                                           NursDetFactor  \
# 0     LabourAvailability IrrigWaterAvailability PreM...
# 1     CalendarDate SeedAvailability IrrigWaterAvaila...
# 2     PreMonsoonShowers IrrigWaterAvailability Labou...
# 3     CalendarDate IrrigWaterAvailability LabourAvai...
# 4               SeedAvailability IrrigWaterAvailability
# ...                                                 ...
# 1285                                 LabourAvailability
# 1286  CalendarDate PreMonsoonShowers IrrigWaterAvail...
# 1287                      CalendarDate SeedAvailability
# 1288                CalendarDate IrrigWaterAvailability
# 1289  CalendarDate IrrigWaterAvailability SeedAvaila...
#
#                                          TransDetFactor  \
# 0     IrrigWaterAvailability LaborAvailability RainA...
# 1     CalendarDate SeedlingAge IrrigWaterAvailabilit...
# 2     SeedlingAge RainArrival IrrigWaterAvailability...
# 3     CalendarDate SeedlingAge RainArrival IrrigWate...
# 4     SeedlingAge IrrigWaterAvailability LaborAvaila...
# ...                                                 ...
# 1285  LaborAvailability IrrigWaterAvailability Calen...
# 1286  CalendarDate SeedlingAge RainArrival IrrigWate...
# 1287    CalendarDate SeedlingAge IrrigWaterAvailability
# 1288                           CalendarDate SeedlingAge
# 1289    CalendarDate SeedlingAge IrrigWaterAvailability
#
#       TransplantingIrrigationHours TransplantingIrrigationSource  \
# 0                              2.0                        Boring
# 1                              2.0                         Canal
# 2                              4.0                         Canal
# 3                              2.0                        Boring
# 4                              6.0                        Boring
# ...                            ...                           ...
# 1285                           3.0                        Boring
# 1286                           2.0                        Boring
# 1287                           2.0                        Boring
# 1288                           2.0                        Boring
# 1289                           2.0                        Boring
#
#      TransplantingIrrigationPowerSource  TransIrriCost  StandingWater  \
# 0                                Diesel          200.0            2.0
# 1                                   NaN            NaN            3.0
# 2                                   NaN            NaN           10.0
# 3                                Diesel            NaN            NaN
# 4                              Electric          400.0            NaN
# ...                                 ...            ...            ...
# 1285                           Electric          200.0            2.0
# 1286                             Diesel          300.0            2.0
# 1287                           Electric          200.0            2.0
# 1288                           Electric          500.0            3.0
# 1289                           Electric          100.0            4.0
#
#      OrgFertilizers  Ganaura  CropOrgFYM PCropSolidOrgFertAppMethod  \
# 0               FYM      NaN         2.0                SoilApplied
# 1               NaN      NaN         NaN                        NaN
# 2           Ganaura      2.0         NaN               Broadcasting
# 3               FYM      NaN         5.0                SoilApplied
# 4               NaN      NaN         NaN                        NaN
# ...             ...      ...         ...                        ...
# 1285            FYM      NaN         3.0                SoilApplied
# 1286            FYM      NaN         5.0                SoilApplied
# 1287            FYM      NaN        15.0                SoilApplied
# 1288            NaN      NaN         NaN                        NaN
# 1289            NaN      NaN         NaN                        NaN
#
#       NoFertilizerAppln CropbasalFerts  BasalDAP  BasalUrea  \
# 0                     3            DAP       6.0        NaN
# 1                     3            DAP       5.0        NaN
# 2                     2       DAP Urea       9.0       18.0
# 3                     2            DAP      15.0        NaN
# 4                     2       DAP Urea      20.0       15.0
# ...                 ...            ...       ...        ...
# 1285                  3            DAP      12.0        NaN
# 1286                  1            DAP      20.0        NaN
# 1287                  3      DAP Other       6.0        NaN
# 1288                  3            NaN       NaN        NaN
# 1289                  1       DAP Urea       5.0       10.0
#
#      MineralFertAppMethod FirstTopDressFert  1tdUrea  1appDaysUrea  2tdUrea  \
# 0            Broadcasting              Urea      8.0          23.0      6.0
# 1            Broadcasting              Urea      7.0          23.0      8.0
# 2            Broadcasting              Urea      9.0          38.0      NaN
# 3             SoilApplied              Urea      9.0          30.0      NaN
# 4            Broadcasting              Urea     15.0          40.0      NaN
# ...                   ...               ...      ...           ...      ...
# 1285         Broadcasting              Urea     13.0          23.0     12.0
# 1286          SoilApplied               NaN      NaN           NaN      NaN
# 1287          SoilApplied              Urea      6.0          30.0      3.0
# 1288         Broadcasting        Urea Other      2.0          30.0      2.0
# 1289         Broadcasting               NaN      NaN           NaN      NaN
#
#       2appDaysUrea MineralFertAppMethod.1 Harv_method   Harv_date  \
# 0             63.0           Broadcasting        hand  2022-12-02
# 1             65.0           Broadcasting        hand  2022-11-12
# 2              NaN           Broadcasting        hand  2022-11-24
# 3              NaN            SoilApplied        hand  2022-10-15
# 4              NaN           Broadcasting     machine  2022-11-20
# ...            ...                    ...         ...         ...
# 1285          64.0           Broadcasting        hand  2022-12-01
# 1286           NaN                    NaN        hand  2022-10-15
# 1287          55.0           Broadcasting        hand  2022-10-28
# 1288          60.0           Broadcasting        hand  2022-11-25
# 1289           NaN                    NaN        hand  2022-11-04
#
#       Harv_hand_rent Threshing_date Threshing_method  Residue_length  \
# 0              500.0     2022-12-28             hand              22
# 1              150.0     2022-12-20          machine              28
# 2             1200.0     2022-12-05          machine              28
# 3              300.0     2022-10-25             hand              30
# 4                NaN     2022-11-20          machine              26
# ...              ...            ...              ...             ...
# 1285          1200.0     2022-12-23             hand              23
# 1286           450.0     2022-10-20             hand              28
# 1287           600.0     2022-11-12             hand              29
# 1288            90.0     2023-01-28             hand              29
# 1289           250.0     2023-01-09          machine              26
#
#       Residue_perc     Stubble_use      Acre
# 0               10  plowed_in_soil  0.272727
# 1               10  plowed_in_soil  0.227273
# 2               10  plowed_in_soil  0.281250
# 3               10  plowed_in_soil  0.136364
# 4               40  plowed_in_soil  0.312500
# ...            ...             ...       ...
# 1285            10  plowed_in_soil  0.500000
# 1286            10  plowed_in_soil  0.181818
# 1287            10  plowed_in_soil  0.136364
# 1288            10  plowed_in_soil  0.227273
# 1289            10  plowed_in_soil  0.156250
#
# [1290 rows x 43 columns]

# %%
train
# Out:
#                    ID  District      Block  CultLand  CropCultLand  \
# 0     ID_GTFAC7PEVWQ9   Nalanda  Noorsarai        45            40
# 1     ID_TK40ARLSPOKS   Nalanda     Rajgir        26            26
# 2     ID_1FJY2CRIMLZZ      Gaya      Gurua        10            10
# 3     ID_I3IPXS4DB7NE      Gaya      Gurua        15            15
# 4     ID_4T8YQWXWHB4A   Nalanda  Noorsarai        60            60
# ...               ...       ...        ...       ...           ...
# 3865  ID_7ZZQ6R4XB4FK   Nalanda     Rajgir        28            28
# 3866  ID_PVVDF6LK6FO8  Vaishali      Mahua         5             5
# 3867  ID_RBYVUPRATVMW   Nalanda  Noorsarai        50            45
# 3868  ID_ARE9QWENJNJ2     Jamui     Khaira        20            20
# 3869  ID_KEPOQDTCZC6S     Jamui      Jamui         4             4
#
#                                   LandPreparationMethod CropTillageDate  \
# 0                  TractorPlough FourWheelTracRotavator      2022-07-20
# 1     WetTillagePuddling TractorPlough FourWheelTrac...      2022-07-18
# 2                  TractorPlough FourWheelTracRotavator      2022-06-30
# 3                  TractorPlough FourWheelTracRotavator      2022-06-16
# 4                      TractorPlough WetTillagePuddling      2022-07-19
# ...                                                 ...             ...
# 3865  WetTillagePuddling TractorPlough FourWheelTrac...      2022-07-02
# 3866  WetTillagePuddling TractorPlough FourWheelTrac...      2022-07-06
# 3867                                      TractorPlough      2022-07-07
# 3868                                      TractorPlough      2022-07-12
# 3869                                      TractorPlough      2022-07-24
#
#       CropTillageDepth           CropEstMethod RcNursEstDate  \
# 0                    5    Manual_PuddledRandom    2022-06-27
# 1                    5    Manual_PuddledRandom    2022-06-20
# 2                    6    Manual_PuddledRandom    2022-06-20
# 3                    6    Manual_PuddledRandom    2022-06-17
# 4                    4    Manual_PuddledRandom    2022-06-21
# ...                ...                     ...           ...
# 3865                 6  LineSowingAfterTillage    2022-06-29
# 3866                 5    Manual_PuddledRandom    2022-07-08
# 3867                 5    Manual_PuddledRandom    2022-06-15
# 3868                 3    Manual_PuddledRandom    2022-06-28
# 3869                 4    Manual_PuddledRandom    2022-06-25
#
#      SeedingSowingTransplanting  SeedlingsPerPit  \
# 0                    2022-07-21              2.0
# 1                    2022-07-20              2.0
# 2                    2022-08-13              2.0
# 3                    2022-07-17              2.0
# 4                    2022-07-20              2.0
# ...                         ...              ...
# 3865                 2022-07-16              NaN
# 3866                 2022-07-30              1.0
# 3867                 2022-07-08              1.0
# 3868                 2022-07-24              4.0
# 3869                 2022-07-28             10.0
#
#                                           NursDetFactor  \
# 0     CalendarDate IrrigWaterAvailability SeedAvaila...
# 1     CalendarDate PreMonsoonShowers IrrigWaterAvail...
# 2     PreMonsoonShowers IrrigWaterAvailability Labou...
# 3     CalendarDate PreMonsoonShowers IrrigWaterAvail...
# 4     CalendarDate IrrigWaterAvailability SeedAvaila...
# ...                                                 ...
# 3865                                                NaN
# 3866          IrrigWaterAvailability LabourAvailability
# 3867                CalendarDate IrrigWaterAvailability
# 3868            SeedAvailability IrrigWaterAvailability
# 3869           PreMonsoonShowers IrrigWaterAvailability
#
#                                          TransDetFactor  \
# 0     CalendarDate SeedlingAge RainArrival IrrigWate...
# 1     CalendarDate SeedlingAge RainArrival IrrigWate...
# 2     SeedlingAge IrrigWaterAvailability LaborAvaila...
# 3     CalendarDate SeedlingAge RainArrival IrrigWate...
# 4     SeedlingAge RainArrival IrrigWaterAvailability...
# ...                                                 ...
# 3865                                                NaN
# 3866           IrrigWaterAvailability LaborAvailability
# 3867                CalendarDate IrrigWaterAvailability
# 3868     IrrigWaterAvailability RainArrival SeedlingAge
# 3869                            SeedlingAge RainArrival
#
#       TransplantingIrrigationHours TransplantingIrrigationSource  \
# 0                              5.0                        Boring
# 1                              5.0                        Boring
# 2                              4.0                        Boring
# 3                              NaN                           NaN
# 4                              9.0                        Boring
# ...                            ...                           ...
# 3865                           7.0                        Boring
# 3866                           3.0                        Boring
# 3867                           6.0                        Boring
# 3868                           2.0                         Canal
# 3869                           5.0                        Boring
#
#      TransplantingIrrigationPowerSource  TransIrriCost  StandingWater  \
# 0                              Electric          200.0            2.0
# 1                              Electric          125.0            3.0
# 2                              Electric           80.0            2.0
# 3                                   NaN            NaN            NaN
# 4                              Electric          300.0            2.0
# ...                                 ...            ...            ...
# 3865                           Electric          360.0            5.0
# 3866                             Diesel            NaN            3.0
# 3867                           Electric          120.0            5.0
# 3868                                NaN            NaN            9.0
# 3869                           Electric          500.0            2.0
#
#      OrgFertilizers  Ganaura  CropOrgFYM PCropSolidOrgFertAppMethod  \
# 0               NaN      NaN         NaN                        NaN
# 1               NaN      NaN         NaN                        NaN
# 2       Ganaura FYM      1.0         1.0                SoilApplied
# 3           Ganaura      1.0         NaN                SoilApplied
# 4               NaN      NaN         NaN                        NaN
# ...             ...      ...         ...                        ...
# 3865        Ganaura      1.0         NaN                SoilApplied
# 3866            NaN      NaN         NaN                        NaN
# 3867        Ganaura      1.0         NaN               Broadcasting
# 3868            NaN      NaN         NaN                        NaN
# 3869            NaN      NaN         NaN                        NaN
#
#       NoFertilizerAppln CropbasalFerts  BasalDAP  BasalUrea  \
# 0                     2           Urea       NaN       20.0
# 1                     2       DAP Urea      15.0       10.0
# 2                     2            DAP       4.0        NaN
# 3                     2       DAP Urea       6.0        3.0
# 4                     2       Urea DAP      15.0       30.0
# ...                 ...            ...       ...        ...
# 3865                  2       DAP Urea      18.0       12.0
# 3866                  3            DAP       6.0        NaN
# 3867                  1           Urea       NaN       24.0
# 3868                  1       DAP Urea       7.0       10.0
# 3869                  2       DAP Urea      10.0       10.0
#
#      MineralFertAppMethod FirstTopDressFert  1tdUrea  1appDaysUrea  2tdUrea  \
# 0            Broadcasting              Urea     15.0          18.0      NaN
# 1            Broadcasting              Urea     20.0          39.0      NaN
# 2             SoilApplied              Urea      5.0          65.0      NaN
# 3            Broadcasting              Urea      5.0           5.0      NaN
# 4            Broadcasting              Urea     30.0          26.0      NaN
# ...                   ...               ...      ...           ...      ...
# 3865         Broadcasting              Urea     12.0          45.0      NaN
# 3866      RootApplication              Urea      6.0          45.0      6.0
# 3867         Broadcasting               NaN      NaN           NaN      NaN
# 3868         Broadcasting               NaN      NaN           NaN      NaN
# 3869         Broadcasting              Urea     10.0          28.0      NaN
#
#       2appDaysUrea MineralFertAppMethod.1 Harv_method   Harv_date  \
# 0              NaN           Broadcasting     machine  2022-11-16
# 1              NaN           Broadcasting        hand  2022-11-25
# 2              NaN        RootApplication        hand  2022-12-12
# 3              NaN           Broadcasting        hand  2022-12-02
# 4              NaN           Broadcasting     machine  2022-11-30
# ...            ...                    ...         ...         ...
# 3865           NaN           Broadcasting     machine  2022-11-29
# 3866           6.0           Broadcasting        hand  2022-10-10
# 3867           NaN                    NaN        hand  2022-10-20
# 3868           NaN                    NaN        hand  2022-11-09
# 3869           NaN           Broadcasting        hand  2022-11-17
#
#       Harv_hand_rent Threshing_date Threshing_method  Residue_length  \
# 0                NaN     2022-11-16          machine              30
# 1                3.0     2022-12-24          machine              24
# 2              480.0     2023-01-11          machine              30
# 3              240.0     2022-12-29             hand              26
# 4                NaN     2022-12-02          machine              24
# ...              ...            ...              ...             ...
# 3865             NaN     2022-12-14          machine              25
# 3866             4.0     2022-11-05             hand              30
# 3867          1200.0     2022-10-30             hand              25
# 3868           100.0     2022-12-10             hand              25
# 3869           300.0     2022-12-29          machine              27
#
#       Residue_perc     Stubble_use      Acre  Yield
# 0               40  plowed_in_soil  0.312500    600
# 1               10  plowed_in_soil  0.312500    600
# 2               10  plowed_in_soil  0.148148    225
# 3               10  plowed_in_soil  0.222222    468
# 4               40  plowed_in_soil  0.468750    550
# ...            ...             ...       ...    ...
# 3865            40  plowed_in_soil  0.375000    720
# 3866            10  plowed_in_soil  0.136364    250
# 3867            10  plowed_in_soil  0.375000    600
# 3868            10  plowed_in_soil  0.227273    400
# 3869            10  plowed_in_soil  0.136364    238
#
# [3870 rows x 44 columns]

# %%
# train['OrgFertilizers'] = train['OrgFertilizers'].fillna(80.0)
# test['OrgFertilizers'] = test['OrgFertilizers'].fillna(80.0)

for i in range(3870):
    if(train['OrgFertilizers'][i] == 'FYM'):
        train['OrgFertilizers'][i] = 80.0
        train['Ganaura'][i] = 80.0
        
for i in range(1290):
    if(test['OrgFertilizers'][i] == 'FYM'):
        test['OrgFertilizers'][i] = 80.0
        test['Ganaura'][i] = 80.0
# Out:
# C:\Users\Fotsing tchide\AppData\Local\Temp\ipykernel_14852\896028297.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['OrgFertilizers'][i] = 80.0
# C:\Users\Fotsing tchide\AppData\Local\Temp\ipykernel_14852\896028297.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['Ganaura'][i] = 80.0
# C:\Users\Fotsing tchide\AppData\Local\Temp\ipykernel_14852\896028297.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['OrgFertilizers'][i] = 80.0
# C:\Users\Fotsing tchide\AppData\Local\Temp\ipykernel_14852\896028297.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Ganaura'][i] = 80.0

# %%
# train['MineralFertAppMethod'] = train['MineralFertAppMethod'].replace(['Broadcasting','RootApplication','SoilApplied'],[50.0,25.0,15.0])
# test['MineralFertAppMethod'] = test['MineralFertAppMethod'].replace(['Broadcasting','RootApplication','SoilApplied'],[50.0,25.0,15.0])

# train['MineralFertAppMethod.1'] = train['MineralFertAppMethod.1'].replace(['Broadcasting','RootApplication','SoilApplied'],[50.0,25.0,15.0])
# test['MineralFertAppMethod.1'] = test['MineralFertAppMethod.1'].replace(['Broadcasting','RootApplication','SoilApplied'],[50.0,25.0,15.0])

# train['MineralFertAppMethod'] = train['MineralFertAppMethod'].fillna(80.0)
# test['MineralFertAppMethod'] = test['MineralFertAppMethod'].fillna(80.0)

# train['MineralFertAppMethod.1'] = train['MineralFertAppMethod.1'].fillna(80.0)

# %%
# train['Threshing_method'] = train['Threshing_method'].replace(['Broadcasting','RootApplication','SoilApplied'],[60.0,35.0,25.0])
# test['Threshing_method'] = test['Threshing_method'].replace(['Broadcasting','RootApplication','SoilApplied','Spray'],[60.0,35.0,25.0,40.0])

# train['MineralFertAppMethod.1'] = train['MineralFertAppMethod.1'].replace(['Broadcasting','RootApplication','SoilApplied'],[60.0,35.0,25.0])
# test['MineralFertAppMethod.1'] = test['MineralFertAppMethod.1'].replace(['Broadcasting','RootApplication','SoilApplied'],[60.0,35.0,25.0])

# %%
train = train.drop(columns='TransDetFactor')
test = test.drop(columns='TransDetFactor')

train = train.drop(columns='CropTillageDate')
test = test.drop(columns='CropTillageDate')

train = train.drop(columns='RcNursEstDate')
test = test.drop(columns='RcNursEstDate')

train = train.drop(columns='Harv_date')
test = test.drop(columns='Harv_date')

train = train.drop(columns='TransplantingIrrigationPowerSource')
test = test.drop(columns='TransplantingIrrigationPowerSource')

# train = train.drop(columns='OrgFertilizers')
# test = test.drop(columns='OrgFertilizers')

train = train.drop(columns='Stubble_use')
test = test.drop(columns='Stubble_use')


# train = train.drop(columns='Threshing_method')
# test = test.drop(columns='Threshing_method')

train = train.drop(columns='CropEstMethod')
test = test.drop(columns='CropEstMethod')

train = train.drop(columns='SeedingSowingTransplanting')
test = test.drop(columns='SeedingSowingTransplanting')

train = train.drop(columns='Threshing_date')
test = test.drop(columns='Threshing_date')

train = train.drop(columns='NursDetFactor')
test = test.drop(columns='NursDetFactor')

train = train.drop(columns='LandPreparationMethod')
test = test.drop(columns='LandPreparationMethod')

# %%
train['FirstTopDressFert'] = train['FirstTopDressFert'].replace('Urea DAP','DAP Urea')
test['FirstTopDressFert'] = test['FirstTopDressFert'].replace('Urea DAP','DAP Urea')

train['CropbasalFerts'] = train['CropbasalFerts'].replace('Urea DAP','DAP Urea')
test['CropbasalFerts'] = test['CropbasalFerts'].replace('Urea DAP','DAP Urea')

# %%
# set(train['TransplantingIrrigationSource'])

# %%
sn.heatmap(train.isna(),cbar=None )
# Out:
# <Axes: >

# %%
train
# Out:
#                    ID  District      Block  CultLand  CropCultLand  \
# 0     ID_GTFAC7PEVWQ9   Nalanda  Noorsarai        45            40
# 1     ID_TK40ARLSPOKS   Nalanda     Rajgir        26            26
# 2     ID_1FJY2CRIMLZZ      Gaya      Gurua        10            10
# 3     ID_I3IPXS4DB7NE      Gaya      Gurua        15            15
# 4     ID_4T8YQWXWHB4A   Nalanda  Noorsarai        60            60
# ...               ...       ...        ...       ...           ...
# 3865  ID_7ZZQ6R4XB4FK   Nalanda     Rajgir        28            28
# 3866  ID_PVVDF6LK6FO8  Vaishali      Mahua         5             5
# 3867  ID_RBYVUPRATVMW   Nalanda  Noorsarai        50            45
# 3868  ID_ARE9QWENJNJ2     Jamui     Khaira        20            20
# 3869  ID_KEPOQDTCZC6S     Jamui      Jamui         4             4
#
#       CropTillageDepth  SeedlingsPerPit  TransplantingIrrigationHours  \
# 0                    5              2.0                           5.0
# 1                    5              2.0                           5.0
# 2                    6              2.0                           4.0
# 3                    6              2.0                           NaN
# 4                    4              2.0                           9.0
# ...                ...              ...                           ...
# 3865                 6              NaN                           7.0
# 3866                 5              1.0                           3.0
# 3867                 5              1.0                           6.0
# 3868                 3              4.0                           2.0
# 3869                 4             10.0                           5.0
#
#      TransplantingIrrigationSource  TransIrriCost  StandingWater  \
# 0                           Boring          200.0            2.0
# 1                           Boring          125.0            3.0
# 2                           Boring           80.0            2.0
# 3                              NaN            NaN            NaN
# 4                           Boring          300.0            2.0
# ...                            ...            ...            ...
# 3865                        Boring          360.0            5.0
# 3866                        Boring            NaN            3.0
# 3867                        Boring          120.0            5.0
# 3868                         Canal            NaN            9.0
# 3869                        Boring          500.0            2.0
#
#      OrgFertilizers  Ganaura  CropOrgFYM PCropSolidOrgFertAppMethod  \
# 0               NaN      NaN         NaN                        NaN
# 1               NaN      NaN         NaN                        NaN
# 2       Ganaura FYM      1.0         1.0                SoilApplied
# 3           Ganaura      1.0         NaN                SoilApplied
# 4               NaN      NaN         NaN                        NaN
# ...             ...      ...         ...                        ...
# 3865        Ganaura      1.0         NaN                SoilApplied
# 3866            NaN      NaN         NaN                        NaN
# 3867        Ganaura      1.0         NaN               Broadcasting
# 3868            NaN      NaN         NaN                        NaN
# 3869            NaN      NaN         NaN                        NaN
#
#       NoFertilizerAppln CropbasalFerts  BasalDAP  BasalUrea  \
# 0                     2           Urea       NaN       20.0
# 1                     2       DAP Urea      15.0       10.0
# 2                     2            DAP       4.0        NaN
# 3                     2       DAP Urea       6.0        3.0
# 4                     2       Urea DAP      15.0       30.0
# ...                 ...            ...       ...        ...
# 3865                  2       DAP Urea      18.0       12.0
# 3866                  3            DAP       6.0        NaN
# 3867                  1           Urea       NaN       24.0
# 3868                  1       DAP Urea       7.0       10.0
# 3869                  2       DAP Urea      10.0       10.0
#
#      MineralFertAppMethod FirstTopDressFert  1tdUrea  1appDaysUrea  2tdUrea  \
# 0            Broadcasting              Urea     15.0          18.0      NaN
# 1            Broadcasting              Urea     20.0          39.0      NaN
# 2             SoilApplied              Urea      5.0          65.0      NaN
# 3            Broadcasting              Urea      5.0           5.0      NaN
# 4            Broadcasting              Urea     30.0          26.0      NaN
# ...                   ...               ...      ...           ...      ...
# 3865         Broadcasting              Urea     12.0          45.0      NaN
# 3866      RootApplication              Urea      6.0          45.0      6.0
# 3867         Broadcasting               NaN      NaN           NaN      NaN
# 3868         Broadcasting               NaN      NaN           NaN      NaN
# 3869         Broadcasting              Urea     10.0          28.0      NaN
#
#       2appDaysUrea MineralFertAppMethod.1 Harv_method  Harv_hand_rent  \
# 0              NaN           Broadcasting     machine             NaN
# 1              NaN           Broadcasting        hand             3.0
# 2              NaN        RootApplication        hand           480.0
# 3              NaN           Broadcasting        hand           240.0
# 4              NaN           Broadcasting     machine             NaN
# ...            ...                    ...         ...             ...
# 3865           NaN           Broadcasting     machine             NaN
# 3866           6.0           Broadcasting        hand             4.0
# 3867           NaN                    NaN        hand          1200.0
# 3868           NaN                    NaN        hand           100.0
# 3869           NaN           Broadcasting        hand           300.0
#
#      Threshing_method  Residue_length  Residue_perc      Acre  Yield
# 0             machine              30            40  0.312500    600
# 1             machine              24            10  0.312500    600
# 2             machine              30            10  0.148148    225
# 3                hand              26            10  0.222222    468
# 4             machine              24            40  0.468750    550
# ...               ...             ...           ...       ...    ...
# 3865          machine              25            40  0.375000    720
# 3866             hand              30            10  0.136364    250
# 3867             hand              25            10  0.375000    600
# 3868             hand              25            10  0.227273    400
# 3869          machine              27            10  0.136364    238
#
# [3870 rows x 33 columns]

# %%
# pd.merge()

# %%
train['Acre'] = train['Acre']*10
test['Acre'] = test['Acre']*10

# %%
sn.heatmap(train.isna(),cbar=None )
# sn.heatmap(test.isna(),cbar=None )
# Out:
# <Axes: >

# %%
nan_date = '2023-11-9'
nan_word = 'default'

# %%
def valide_date(date):
    try:
        return bool(datetime.datetime.strptime(date,'%Y-%m-%d'))
    except ValueError:
        return False

# %%
origin = datetime.datetime(1970,1,1)
days = (datetime.datetime.strptime('2023-11-9', '%Y-%m-%d') - origin).days
days
datetime.datetime.strptime('2022-07-20', '%Y-%m-%d').month
# Out:
# 7

# %%
# train['Threshing_date'] = train['Threshing_date'].fillna(nan_date)
# test['Threshing_date'] = test['Threshing_date'].fillna(nan_date)

# train['CropTillageD'] = train['Threshing_date'].apply(lambda x :datetime.datetime.strptime(x, '%Y-%m-%d').day)
# test['CropTillageD'] = test['Threshing_date'].apply(lambda x :datetime.datetime.strptime(x, '%Y-%m-%d').day)

# train['CropTillagey'] = train['Threshing_date'].apply(lambda x :datetime.datetime.strptime(x, '%Y-%m-%d').year)
# test['CropTillagey'] = test['Threshing_date'].apply(lambda x :datetime.datetime.strptime(x, '%Y-%m-%d').year)

# train['CropTillagem'] = train['Threshing_date'].apply(lambda x :datetime.datetime.strptime(x, '%Y-%m-%d').month)
# test['CropTillagem'] = test['Threshing_date'].apply(lambda x :datetime.datetime.strptime(x, '%Y-%m-%d').month)

# train = train.drop(columns='Threshing_date')
# test = test.drop(columns='Threshing_date')

# %%
def define_num_values(data, col_name):
    result = None
    size = len(set(data[col_name]))
    keys = list(set(data[col_name]))
#     if(not valide_date(data[col_name][0])):
    values = list(np.arange(1,size+1))
    values = list(np.array(values)/max(values))
    result = dict(list(zip(keys, values)))
#     else:
#         values = list(set(data[col_name].apply(lambda x :datetime.datetime.strptime(x, '%Y-%m-%d').day))) 
#         values = list(np.array(values)/min(values))
#         result = dict(list(zip(keys, values)))
    data[col_name] =  data[col_name].replace(result)

# %%
def epurate_data_to_string_values(data):
    define_num_values(data, 'District')
    define_num_values(data, 'Block')
#     define_num_values(data, 'LandPreparationMethod')
#     define_num_values(data, 'CropTillageDate')
#     define_num_values(data, 'Threshing_date')

#     data['RcNursEstDate'] = data['RcNursEstDate'].fillna(nan_date)
#     define_num_values(data, 'RcNursEstDate')

#     define_num_values(data, 'SeedingSowingTransplanting')

#     data['NursDetFactor'] = data['NursDetFactor'].fillna(nan_word)
#     define_num_values(data, 'NursDetFactor')

#     data['TransDetFactor'] = data['TransDetFactor'].fillna(nan_word)
#     define_num_values(data, 'TransDetFactor')

    data['TransplantingIrrigationSource'] = data['TransplantingIrrigationSource'].fillna(nan_word)
    define_num_values(data, 'TransplantingIrrigationSource')

#     data['TransplantingIrrigationPowerSource'] = data['TransplantingIrrigationPowerSource'].fillna(nan_word)
#     define_num_values(data, 'TransplantingIrrigationPowerSource')

    data['OrgFertilizers'] = data['OrgFertilizers'].fillna(nan_word)
    define_num_values(data, 'OrgFertilizers')

    data['PCropSolidOrgFertAppMethod'] = data['PCropSolidOrgFertAppMethod'].fillna(nan_word)
    define_num_values(data, 'PCropSolidOrgFertAppMethod')

    data['CropbasalFerts'] = data['CropbasalFerts'].fillna(nan_word)
    define_num_values(data, 'CropbasalFerts')

    define_num_values(data, 'MineralFertAppMethod')

    data['FirstTopDressFert'] = data['FirstTopDressFert'].fillna(nan_word)
    define_num_values(data, 'FirstTopDressFert')

    data['2tdUrea'] = data['2tdUrea'].fillna(0.01)
    data['2appDaysUrea'] = data['2appDaysUrea'].fillna(0.01)

    data['MineralFertAppMethod.1'] = data['MineralFertAppMethod.1'].fillna(nan_word)
    define_num_values(data, 'MineralFertAppMethod.1')

    define_num_values(data, 'Harv_method')
#     define_num_values(data, 'Harv_date')

#     define_num_values(data, 'Threshing_date')
    define_num_values(data, 'Threshing_method')
#     define_num_values(data, 'Stubble_use')

# %%
epurate_data_to_string_values(train)
epurate_data_to_string_values(test)

# %%
# train['CropCultLand'] = train['CropCultLand']/max(train['CropCultLand'])
# test['CropCultLand'] = test['CropCultLand']/max(test['CropCultLand'])

# train['CultLand'] = train['CultLand']/max(train['CultLand'])
# test['CultLand'] = test['CultLand']/max(test['CultLand'])

# train['CropTillageDepth'] = train['CropTillageDepth']/max(train['CropTillageDepth'])
# test['CropTillageDepth'] = test['CropTillageDepth']/max(test['CropTillageDepth'])

# train['Residue_length'] = train['Residue_length']/max(train['Residue_length'])
# test['Residue_length'] = test['Residue_length']/max(test['Residue_length'])

# %%
train
# Out:
#                    ID  District     Block  CultLand  CropCultLand  \
# 0     ID_GTFAC7PEVWQ9      0.50  0.888889        45            40
# 1     ID_TK40ARLSPOKS      0.50  1.000000        26            26
# 2     ID_1FJY2CRIMLZZ      0.25  0.222222        10            10
# 3     ID_I3IPXS4DB7NE      0.25  0.222222        15            15
# 4     ID_4T8YQWXWHB4A      0.50  0.888889        60            60
# ...               ...       ...       ...       ...           ...
# 3865  ID_7ZZQ6R4XB4FK      0.50  1.000000        28            28
# 3866  ID_PVVDF6LK6FO8      1.00  0.555556         5             5
# 3867  ID_RBYVUPRATVMW      0.50  0.888889        50            45
# 3868  ID_ARE9QWENJNJ2      0.75  0.111111        20            20
# 3869  ID_KEPOQDTCZC6S      0.75  0.444444         4             4
#
#       CropTillageDepth  SeedlingsPerPit  TransplantingIrrigationHours  \
# 0                    5              2.0                           5.0
# 1                    5              2.0                           5.0
# 2                    6              2.0                           4.0
# 3                    6              2.0                           NaN
# 4                    4              2.0                           9.0
# ...                ...              ...                           ...
# 3865                 6              NaN                           7.0
# 3866                 5              1.0                           3.0
# 3867                 5              1.0                           6.0
# 3868                 3              4.0                           2.0
# 3869                 4             10.0                           5.0
#
#       TransplantingIrrigationSource  TransIrriCost  StandingWater  \
# 0                          1.000000          200.0            2.0
# 1                          1.000000          125.0            3.0
# 2                          1.000000           80.0            2.0
# 3                          0.428571            NaN            NaN
# 4                          1.000000          300.0            2.0
# ...                             ...            ...            ...
# 3865                       1.000000          360.0            5.0
# 3866                       1.000000            NaN            3.0
# 3867                       1.000000          120.0            5.0
# 3868                       0.714286            NaN            9.0
# 3869                       1.000000          500.0            2.0
#
#       OrgFertilizers  Ganaura  CropOrgFYM  PCropSolidOrgFertAppMethod  \
# 0            0.87500      NaN         NaN                         0.4
# 1            0.87500      NaN         NaN                         0.4
# 2            0.25000      1.0         1.0                         1.0
# 3            0.28125      1.0         NaN                         1.0
# 4            0.87500      NaN         NaN                         0.4
# ...              ...      ...         ...                         ...
# 3865         0.28125      1.0         NaN                         1.0
# 3866         0.87500      NaN         NaN                         0.4
# 3867         0.28125      1.0         NaN                         0.6
# 3868         0.87500      NaN         NaN                         0.4
# 3869         0.87500      NaN         NaN                         0.4
#
#       NoFertilizerAppln  CropbasalFerts  BasalDAP  BasalUrea  \
# 0                     2        0.342857       NaN       20.0
# 1                     2        0.085714      15.0       10.0
# 2                     2        0.942857       4.0        NaN
# 3                     2        0.085714       6.0        3.0
# 4                     2        0.485714      15.0       30.0
# ...                 ...             ...       ...        ...
# 3865                  2        0.085714      18.0       12.0
# 3866                  3        0.942857       6.0        NaN
# 3867                  1        0.342857       NaN       24.0
# 3868                  1        0.085714       7.0       10.0
# 3869                  2        0.085714      10.0       10.0
#
#       MineralFertAppMethod  FirstTopDressFert  1tdUrea  1appDaysUrea  2tdUrea  \
# 0                 1.000000                0.4     15.0          18.0     0.01
# 1                 1.000000                0.4     20.0          39.0     0.01
# 2                 0.333333                0.4      5.0          65.0     0.01
# 3                 1.000000                0.4      5.0           5.0     0.01
# 4                 1.000000                0.4     30.0          26.0     0.01
# ...                    ...                ...      ...           ...      ...
# 3865              1.000000                0.4     12.0          45.0     0.01
# 3866              0.666667                0.4      6.0          45.0     6.00
# 3867              1.000000                0.2      NaN           NaN     0.01
# 3868              1.000000                0.2      NaN           NaN     0.01
# 3869              1.000000                0.4     10.0          28.0     0.01
#
#       2appDaysUrea  MineralFertAppMethod.1  Harv_method  Harv_hand_rent  \
# 0             0.01                    0.75          0.5             NaN
# 1             0.01                    0.75          1.0             3.0
# 2             0.01                    0.50          1.0           480.0
# 3             0.01                    0.75          1.0           240.0
# 4             0.01                    0.75          0.5             NaN
# ...            ...                     ...          ...             ...
# 3865          0.01                    0.75          0.5             NaN
# 3866          6.00                    0.75          1.0             4.0
# 3867          0.01                    1.00          1.0          1200.0
# 3868          0.01                    1.00          1.0           100.0
# 3869          0.01                    0.75          1.0           300.0
#
#       Threshing_method  Residue_length  Residue_perc      Acre  Yield
# 0                  0.5              30            40  3.125000    600
# 1                  0.5              24            10  3.125000    600
# 2                  0.5              30            10  1.481481    225
# 3                  1.0              26            10  2.222222    468
# 4                  0.5              24            40  4.687500    550
# ...                ...             ...           ...       ...    ...
# 3865               0.5              25            40  3.750000    720
# 3866               1.0              30            10  1.363636    250
# 3867               1.0              25            10  3.750000    600
# 3868               1.0              25            10  2.272727    400
# 3869               0.5              27            10  1.363636    238
#
# [3870 rows x 33 columns]

# %%
def epurate_data_fill_nan_values(train):
    nan_aprox = 80.0
    train['TransplantingIrrigationHours'] = train['TransplantingIrrigationHours'].fillna(nan_aprox)
    train['StandingWater'] = train['StandingWater'].fillna(nan_aprox)
    train['Ganaura'] = train['Ganaura'].fillna(nan_aprox)
    train['CropOrgFYM'] = train['CropOrgFYM'].fillna(nan_aprox)
    train['1appDaysUrea'] = train['1appDaysUrea'].fillna(nan_aprox)
    train['Harv_hand_rent'] = train['Harv_hand_rent'].fillna(nan_aprox)
    train['BasalUrea'] = train['BasalUrea'].fillna(nan_aprox)
    train['1tdUrea'] = train['1tdUrea'].fillna(nan_aprox)
    train['BasalDAP'] = train['BasalDAP'].fillna(nan_aprox)
    train['TransIrriCost'] = train['TransIrriCost'].fillna(nan_aprox)
    train['SeedlingsPerPit'] = train['SeedlingsPerPit'].fillna(nan_aprox)

# %%
epurate_data_fill_nan_values(train)
epurate_data_fill_nan_values(test)

# %%
# train['Harv_hand_rent'] = (train['Harv_hand_rent']-train['Harv_hand_rent'].mean())/max(train['Harv_hand_rent'])
# test['Harv_hand_rent'] = (test['Harv_hand_rent']-test['Harv_hand_rent'].mean())/max(test['Harv_hand_rent'])

# %%
sn.heatmap(train.isna(),cbar=None )
# Out:
# <Axes: >

# %%
sn.heatmap(test.isna(),cbar=None )
# Out:
# <Axes: >

# %%
train
# Out:
#                    ID  District     Block  CultLand  CropCultLand  \
# 0     ID_GTFAC7PEVWQ9      0.50  0.888889        45            40
# 1     ID_TK40ARLSPOKS      0.50  1.000000        26            26
# 2     ID_1FJY2CRIMLZZ      0.25  0.222222        10            10
# 3     ID_I3IPXS4DB7NE      0.25  0.222222        15            15
# 4     ID_4T8YQWXWHB4A      0.50  0.888889        60            60
# ...               ...       ...       ...       ...           ...
# 3865  ID_7ZZQ6R4XB4FK      0.50  1.000000        28            28
# 3866  ID_PVVDF6LK6FO8      1.00  0.555556         5             5
# 3867  ID_RBYVUPRATVMW      0.50  0.888889        50            45
# 3868  ID_ARE9QWENJNJ2      0.75  0.111111        20            20
# 3869  ID_KEPOQDTCZC6S      0.75  0.444444         4             4
#
#       CropTillageDepth  SeedlingsPerPit  TransplantingIrrigationHours  \
# 0                    5              2.0                           5.0
# 1                    5              2.0                           5.0
# 2                    6              2.0                           4.0
# 3                    6              2.0                          80.0
# 4                    4              2.0                           9.0
# ...                ...              ...                           ...
# 3865                 6             80.0                           7.0
# 3866                 5              1.0                           3.0
# 3867                 5              1.0                           6.0
# 3868                 3              4.0                           2.0
# 3869                 4             10.0                           5.0
#
#       TransplantingIrrigationSource  TransIrriCost  StandingWater  \
# 0                          1.000000          200.0            2.0
# 1                          1.000000          125.0            3.0
# 2                          1.000000           80.0            2.0
# 3                          0.428571           80.0           80.0
# 4                          1.000000          300.0            2.0
# ...                             ...            ...            ...
# 3865                       1.000000          360.0            5.0
# 3866                       1.000000           80.0            3.0
# 3867                       1.000000          120.0            5.0
# 3868                       0.714286           80.0            9.0
# 3869                       1.000000          500.0            2.0
#
#       OrgFertilizers  Ganaura  CropOrgFYM  PCropSolidOrgFertAppMethod  \
# 0            0.87500     80.0        80.0                         0.4
# 1            0.87500     80.0        80.0                         0.4
# 2            0.25000      1.0         1.0                         1.0
# 3            0.28125      1.0        80.0                         1.0
# 4            0.87500     80.0        80.0                         0.4
# ...              ...      ...         ...                         ...
# 3865         0.28125      1.0        80.0                         1.0
# 3866         0.87500     80.0        80.0                         0.4
# 3867         0.28125      1.0        80.0                         0.6
# 3868         0.87500     80.0        80.0                         0.4
# 3869         0.87500     80.0        80.0                         0.4
#
#       NoFertilizerAppln  CropbasalFerts  BasalDAP  BasalUrea  \
# 0                     2        0.342857      80.0       20.0
# 1                     2        0.085714      15.0       10.0
# 2                     2        0.942857       4.0       80.0
# 3                     2        0.085714       6.0        3.0
# 4                     2        0.485714      15.0       30.0
# ...                 ...             ...       ...        ...
# 3865                  2        0.085714      18.0       12.0
# 3866                  3        0.942857       6.0       80.0
# 3867                  1        0.342857      80.0       24.0
# 3868                  1        0.085714       7.0       10.0
# 3869                  2        0.085714      10.0       10.0
#
#       MineralFertAppMethod  FirstTopDressFert  1tdUrea  1appDaysUrea  2tdUrea  \
# 0                 1.000000                0.4     15.0          18.0     0.01
# 1                 1.000000                0.4     20.0          39.0     0.01
# 2                 0.333333                0.4      5.0          65.0     0.01
# 3                 1.000000                0.4      5.0           5.0     0.01
# 4                 1.000000                0.4     30.0          26.0     0.01
# ...                    ...                ...      ...           ...      ...
# 3865              1.000000                0.4     12.0          45.0     0.01
# 3866              0.666667                0.4      6.0          45.0     6.00
# 3867              1.000000                0.2     80.0          80.0     0.01
# 3868              1.000000                0.2     80.0          80.0     0.01
# 3869              1.000000                0.4     10.0          28.0     0.01
#
#       2appDaysUrea  MineralFertAppMethod.1  Harv_method  Harv_hand_rent  \
# 0             0.01                    0.75          0.5            80.0
# 1             0.01                    0.75          1.0             3.0
# 2             0.01                    0.50          1.0           480.0
# 3             0.01                    0.75          1.0           240.0
# 4             0.01                    0.75          0.5            80.0
# ...            ...                     ...          ...             ...
# 3865          0.01                    0.75          0.5            80.0
# 3866          6.00                    0.75          1.0             4.0
# 3867          0.01                    1.00          1.0          1200.0
# 3868          0.01                    1.00          1.0           100.0
# 3869          0.01                    0.75          1.0           300.0
#
#       Threshing_method  Residue_length  Residue_perc      Acre  Yield
# 0                  0.5              30            40  3.125000    600
# 1                  0.5              24            10  3.125000    600
# 2                  0.5              30            10  1.481481    225
# 3                  1.0              26            10  2.222222    468
# 4                  0.5              24            40  4.687500    550
# ...                ...             ...           ...       ...    ...
# 3865               0.5              25            40  3.750000    720
# 3866               1.0              30            10  1.363636    250
# 3867               1.0              25            10  3.750000    600
# 3868               1.0              25            10  2.272727    400
# 3869               0.5              27            10  1.363636    238
#
# [3870 rows x 33 columns]

# %%
# Split data for training and local testing

X = train.drop(['ID', 'Yield'], axis = 1)
y = train.Yield

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 1234)

# %%
# Instantiate model
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
import sklearn.svm as SVR
# model = LogisticRegression(penalty='none')
model = RandomForestRegressor(random_state = 1234)#360.4839203408373

# model = DecisionTreeRegressor()
# model = KNeighborsRegressor(n_neighbors=10)
# Fit model
model.fit(X_train, y_train)

# Make predictions
preds = model.predict(X_test)

# Measure model performance
mean_squared_error(y_test, preds, squared=False)
# Out:
# 375.20280828718865

# %%
# Make predictions on the Zindi test set
test_df = test[X.columns]
preds = model.predict(test_df)

# Create submisiion file to be uploaded to Zindi for scoring
sub = pd.DataFrame({'ID': test.ID, 'Yield': preds})
sub.to_csv('BenchmarkSubmission8.csv', index = False)

sub.head()
# Out:
#                 ID   Yield
# 0  ID_F9XXEXN2ADR2  649.58
# 1  ID_SO3VW2X4QO93  418.27
# 2  ID_UKUQ7JM8E894  504.52
# 3  ID_QUISMWEZR2H4  324.25
# 4  ID_25JGI455VKCZ  566.36
